# %%
import  pandas as pd
import numpy as np
import os

# %% [markdown]
# # converting 12 files of sales into 1 file

# %%
df=pd.read_csv("Sales_April_2019.csv")

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
csv_files = [file for file in os.listdir("C:/Users/DC/Desktop/Data science/sales data") if file.endswith('.csv')]

# %%
csv_files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
 data_frames = []  # A list to hold the DataFrames

for file_name in csv_files:
    df = pd.read_csv(file_name)
    data_frames.append(df)
# asscess = 0 means append row wise and ignore index means no indexing
concatenated_df = pd.concat(data_frames, axis=0, ignore_index=True)

# %%
concatenated_df.to_csv('concatenated_data.csv', index=False)

# %%
dff=pd.read_csv('concatenated_data.csv')

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       248151   AA Batteries (4-pack)                4       3.84
# 1       248152    USB-C Charging Cable                2      11.95
# 2       248153    USB-C Charging Cable                1      11.95
# 3       248154        27in FHD Monitor                1     149.99
# 4       248155    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 11681   259353  AAA Batteries (4-pack)                3       2.99
# 11682   259354                  iPhone                1        700
# 11683   259355                  iPhone                1        700
# 11684   259356  34in Ultrawide Monitor                1     379.99
# 11685   259357    USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      09/17/19 14:44      380 North St, Los Angeles, CA 90001
# ...

# %% [markdown]
# # what is the best month for sales how many earned that month ?

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       248151   AA Batteries (4-pack)                4       3.84
# 1       248152    USB-C Charging Cable                2      11.95
# 2       248153    USB-C Charging Cable                1      11.95
# 3       248154        27in FHD Monitor                1     149.99
# 4       248155    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 11681   259353  AAA Batteries (4-pack)                3       2.99
# 11682   259354                  iPhone                1        700
# 11683   259355                  iPhone                1        700
# 11684   259356  34in Ultrawide Monitor                1     379.99
# 11685   259357    USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      09/17/19 14:44      380 North St, Los Angeles, CA 90001
# ...

# %%
# first we want to add the month colum
#and clean the data
df.isna().sum()  # total numbers of null values per colum
# Out:
# Order ID            40
# Product             40
# Quantity Ordered    40
# Price Each          40
# Order Date          40
# Purchase Address    40
# dtype: int64

# %%
df=df.dropna(how="all")

# %%
df.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df=df[df['Order Date'].str[0:2]!="Or"]    #because there are or charecter in data

# %%
df['Month']=df['Order Date'].str[0:2] # adding month colum

# %%
df['Month']=df['Month'].astype('int32')  # converting month colum d type into int

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       248151   AA Batteries (4-pack)                4       3.84
# 1       248152    USB-C Charging Cable                2      11.95
# 2       248153    USB-C Charging Cable                1      11.95
# 3       248154        27in FHD Monitor                1     149.99
# 4       248155    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 11681   259353  AAA Batteries (4-pack)                3       2.99
# 11682   259354                  iPhone                1        700
# 11683   259355                  iPhone                1        700
# 11684   259356  34in Ultrawide Monitor                1     379.99
# 11685   259357    USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address  Month
# 0      09/17/19 14:44      380 North St, Los Angeles, CA 90001      9
# ...

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month                int32
# dtype: object

# %%
df['Quantity Ordered']=pd.to_numeric(df['Quantity Ordered'])  # converting month colum d type into int

# %%
df['Price Each']=pd.to_numeric(df['Price Each'])  # converting month colum d type into int

# %%
df["sales"]=df['Price Each']*df['Quantity Ordered'] # adding sales colum

# %%
df
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 0       248151   AA Batteries (4-pack)                 4        3.84
# 1       248152    USB-C Charging Cable                 2       11.95
# 2       248153    USB-C Charging Cable                 1       11.95
# 3       248154        27in FHD Monitor                 1      149.99
# 4       248155    USB-C Charging Cable                 1       11.95
# ...        ...                     ...               ...         ...
# 11681   259353  AAA Batteries (4-pack)                 3        2.99
# 11682   259354                  iPhone                 1      700.00
# 11683   259355                  iPhone                 1      700.00
# 11684   259356  34in Ultrawide Monitor                 1      379.99
# 11685   259357    USB-C Charging Cable                 1       11.95
#
#            Order Date                         Purchase Address  Month   sales  \
# ...

# %% [markdown]
# # Add colum of city

# %%
df['city']=df['Purchase Address'].apply(lambda x :x.split(',')[1])

# %%
df
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 0       248151   AA Batteries (4-pack)                 4        3.84
# 1       248152    USB-C Charging Cable                 2       11.95
# 2       248153    USB-C Charging Cable                 1       11.95
# 3       248154        27in FHD Monitor                 1      149.99
# 4       248155    USB-C Charging Cable                 1       11.95
# ...        ...                     ...               ...         ...
# 11681   259353  AAA Batteries (4-pack)                 3        2.99
# 11682   259354                  iPhone                 1      700.00
# 11683   259355                  iPhone                 1      700.00
# 11684   259356  34in Ultrawide Monitor                 1      379.99
# 11685   259357    USB-C Charging Cable                 1       11.95
#
#            Order Date                         Purchase Address  Month   sales  \
# ...
